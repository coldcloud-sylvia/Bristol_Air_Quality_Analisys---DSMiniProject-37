# %%
from pandas import read_csv
from datetime import datetime

def parse(x,y,z,e):
    return datetime.strptime(x, '%Y %m %d %H')
dataset = read_csv('traffic.csv', parse_dates = [['Year', 'Month', 'Day', 'Hour']], index_col=0, date_parser=parse)
# Out:
# /var/folders/rx/syngpn293r777jjt54hmtgyr0000gn/T/ipykernel_77905/1556358989.py:6: FutureWarning:
#         Use pd.to_datetime instead.
#
#   dataset = read_csv('traffic.csv', parse_dates = [['Year', 'Month', 'Day', 'Hour']], index_col=0, date_parser=parse)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py:1086, in _make_date_converter.<locals>.converter(*date_cols)
#    1084 try:
#    1085     result = tools.to_datetime(
# -> 1086         date_parser(*date_cols), errors="ignore", cache=cache_dates
#    1087     )
#    1088     if isinstance(result, datetime.datetime):
#
# Input In [4], in parse(x, y, z, e)
#       4 def parse(x,y,z,e):
# ----> 5     return datetime.strptime(x, '%Y %m %d %H')
#
# TypeError: strptime() argument 1 must be str, not numpy.ndarray
#
# ...
